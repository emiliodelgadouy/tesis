# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
from utils.Dataset import Dataset

# %%
dataset_lateralized= Dataset(reduced=False, n=100, lateralize=True)
dataset_lateralized[dataset_lateralized["laterality"]=="R"].head(5).render()
# Out:
# Flip BBoxes: 100%|██████████| 20486/20486 [00:01<00:00, 15039.58it/s]
# ...
# Output()

# %%
dataset_lateralized[dataset_lateralized["laterality"]=="L"].head(1).render()
# dataset_lateralized.render()
# Out:
# ...
# Output()

# %%
dataset_lateralized._flip_map
# Out:
# {}

# %%
dataset_lateralized[dataset_lateralized["laterality"]=="L"].iloc[2]["path"]
# Out:
# 'utils/images_original/7c51789da6c462e55bcb95c2a7d437ee/f581ef53bb7e61f4575db33eceac8ff8.png'

# %%
from matplotlib import pyplot as plt
plt.imshow(dataset_lateralized._get_image(dataset_lateralized[dataset_lateralized["laterality"]=="L"].iloc[1]["path"]).astype("int"), cmap='gray')
