# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
from data.Dataset import Dataset
from data.PatchSequence import PatchSequence
# Out:
# 2025-08-02 10:46:43.230660: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-02 10:46:43.777112: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754142403.952581    6147 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754142404.012360    6147 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1754142404.465996    6147 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754142404.466091    6147 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754142404.466099    6147 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754142404.466106    6147 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-02 10:46:44.525352: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dataset = Dataset(lateralize=False,)
dataset.head()
# Out:
#   laterality view  breast_birads  finding_birads     split        xmin  \
# 0          R   CC              4               4  training  485.695624
# 1          R  MLO              4               4  training  532.399692
# 2          R   CC              3               3  training  368.152714
# 3          R  MLO              3               3  training  162.492921
# 4          R   CC              4               4  training  403.582493
#
#           ymin        xmax         ymax  \
# 0   985.773942  609.595900  1078.419728
# 1   743.812744  639.422675   812.095390
# 2   499.060222  816.519337  1287.129503
# 3   726.730749  729.029452  1105.680056
# 4  1078.254802  580.267104  1203.183844
#
#                                                 path  findings
# 0  data/images_original/48575a27b7c992427041a82fa...         1
# 1  data/images_original/48575a27b7c992427041a82fa...         1
# 2  data/images_original/75e8e48933289d70b407379a5...         1
# 3  data/images_original/75e8e48933289d70b407379a5...         1
# 4  data/images_original/c3487424fee1bdd4515b72dc3...         1

# %%
ds_training = dataset[dataset["split"] == "training"]
ds_test = dataset[dataset["split"] == "test"]

# %%
dataset.stats()

# %%
ds_training.stats()

# %%
ds_test.stats()
