# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
from utils.Dataset import Dataset
dataset = Dataset()
dataset= dataset[dataset['findings']==1]
dataset.stats()
# Out:
# 0       4
# 1       4
# 2       3
# 3       3
# 4       4
#        ..
# 2249    4
# 2250    4
# 2251    4
# 2252    4
# 2253    4
# Name: breast_birads, Length: 2254, dtype: Int64
# 0       R
# 1       R
# 2       R
# 3       R
# 4       R
#        ..
# 2249    R
# 2250    R
# 2251    R
# 2252    L
# 2253    L
# Name: laterality, Length: 2254, dtype: object
# 0        CC
# 1       MLO
# 2        CC
# 3       MLO
# 4        CC
#        ...
# 2249    MLO
# 2250    MLO
# 2251    MLO
# 2252    MLO
# 2253     CC
# Name: view, Length: 2254, dtype: object
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2249    1
# 2250    1
# 2251    1
# 2252    1
# 2253    1
# Name: findings, Length: 2254, dtype: int64
# 0       training
# 1       training
# 2       training
# 3       training
# 4       training
#           ...
# 2249        test
# 2250        test
# 2251        test
# 2252    training
# 2253    training
# Name: split, Length: 2254, dtype: object
# ...
